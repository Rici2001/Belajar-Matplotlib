# %% [markdown]
# ## Import modules :
#
# - kita akan memasukan majic komen yaitu %matplotlib inline berfungsi untuk mendirek hasil output nantinya ataub bisa di bilang hasil matplotlib akan di tampilkan di jupyter notebook
#
# - Dan kita juga mengimport 2 modul yaitu matplotlib dan numpy
#
# - %matplotlib notebook

# %%
# %matplotlib notebook

# %%
import matplotlib 
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# - Setelah itu kita akan mengecheck versi dari matplotlib dan numpy yang kita gunakan saat ini

# %%
print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.3.2
# 1.19.2

# %% [markdown]
# ## Sample dataset
#
# - menyiapkan sebuah variabel yang menampung beberapa nilai
#
# - menggunakan fungsi np.linspace
#
# - np.meshgrid menghasilkan 2 buah array

# %%
n = np.linspace(-3.0, 3.0, 100)

x, y = np.meshgrid(n, n)
z = np.sqrt(x**2 + y**2)

print(x.shape)
print(y.shape)
print(z.shape)
# Out:
# (100, 100)
# (100, 100)
# (100, 100)

# %% [markdown]
# ## 3D Wireframe
#
# - hasil nya bisa di rotasikan
#
# - dikarenakan kita menggunakan matplotlib notebook

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot_wireframe(x, y, z, color='orange')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('3D Wireframe')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %% [markdown]
# ## 3D Surface Plot
#
# - sama dengan sebelumnya, hanya saja ini membuat graph menjadi 2D

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot_surface(x, y, z, color='orange')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('3D Surface plot')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot_surface(x, y, z, cmap='viridis')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('3D Surface plot')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
