# %% [markdown]
# ## Plot Lifecycle

# %% [markdown]
# ## Import modules :
# - kita akan memasukan majic komen yaitu %matplotlib inline berfungsi untuk mendirek hasil output nantinya ataub bisa di bilang hasil matplotlib akan di tampilkan di jupyter notebook
#
# - Dan kita juga mengimport 2 modul yaitu matplotlib dan numpy
#
# - %matplotlib notebook

# %%
# %matplotlib notebook

# %%
import matplotlib 
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# - Setelah itu kita akan mengecheck versi dari matplotlib dan numpy yang kita gunakan saat ini

# %%
print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.3.2
# 1.19.2

# %% [markdown]
# ## Sample data
#
# - mempersiapkan data yang dibentuk dari dictionary
#
# - struktur dictionary merupakan struktur data yang terdiri dari pasangan keys dan values

# %%
data = {'Item A': 109438,
        'Item B': 103569,
        'Item C': 112214,
        'Item D': 112591,
        'Item E': 100934,
        'Item F': 103660,
        'Item G': 137351,
        'Item H': 123381,
        'Item I': 135841,
        'Item J': 104437}

data
# Out:
# {'Item A': 109438,
#  'Item B': 103569,
#  'Item C': 112214,
#  'Item D': 112591,
#  'Item E': 100934,
#  'Item F': 103660,
#  'Item G': 137351,
#  'Item H': 123381,
#  'Item I': 135841,
#  'Item J': 104437}

# %%
items = tuple(data.keys())
items
# Out:
# ('Item A',
#  'Item B',
#  'Item C',
#  'Item D',
#  'Item E',
#  'Item F',
#  'Item G',
#  'Item H',
#  'Item I',
#  'Item J')

# %%
count = tuple(data.values())
count
# Out:
# (109438,
#  103569,
#  112214,
#  112591,
#  100934,
#  103660,
#  137351,
#  123381,
#  135841,
#  104437)

# %% [markdown]
# ## Simple plot
#
# - menggunakan fungsi plt.subplots

# %%
fig, ax = plt.subplots()

ax.barh(items, count)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %% [markdown]
# ## Pengaturan Style
#
# - plt.style.available digunakan untuk mengecek style apa aja yang bisa digunakan

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('bmh')

fig, ax = plt.subplots()
ax.barh(items, count)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %% [markdown]
# ## Pengaturan Tick Label
#
# - parameter alignment diberi nilai right

# %%
fig, ax = plt.subplots()
ax.barh(items, count)

labels = ax.get_xticklabels()

# set property
plt.setp(labels,
         rotation=45,
         horizontalalignment='right')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %% [markdown]
# ## Pengaturan Format pada Ticker

# %%
from matplotlib.ticker import FuncFormatter

# %%
def ribuan(x, pos):
    return f'{int(x/1000)}K'

# %%
fig, ax = plt.subplots()
ax.barh(items, count)

formatter = FuncFormatter(ribuan)
ax.xaxis.set_major_formatter(formatter)

ax.set(title='Contoh Plot',
       xlabel ='Jumlah',
       ylabel ='Items')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %% [markdown]
# ## Pengaturan Label pada Sumbu axis dan judul title
#
# - dengan memanggil method save

# %%
fig, ax = plt.subplots()
ax.barh(items, count)

ax.set(title='Contoh Plot',
       xlabel ='Jumlah',
       ylabel ='Items')
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %% [markdown]
# ## Penambahkan Garis vertikal /horizontal pada plot

# %%
fig, ax = plt.subplots()
ax.barh(items, count)

ax.axvline(80000, 
         ls = '-',
         color ='green')

ax.set(title='Contoh Plot',
       xlabel ='Jumlah',
       ylabel ='Items')

ax.set(title='Contoh Plot',
       xlabel ='Jumlah',
       ylabel ='items')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %% [markdown]
# ## Menyimpan Hasil Plot ke dalam suatu File
#
# - mengecek format
#
# - format yang di gunakan png

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %%
fig, ax = plt.subplots()
ax.barh(items, count)

ax.axvline(np.mean(count),
         ls = '--',
         color ='r')

ax.set(title='Contoh Plot',
       xlabel ='Jumlah',
       ylabel ='Items')

fig.savefig('Sales.png', 
            transparent=False,
            dpi = 8)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %% [markdown]
# ##
