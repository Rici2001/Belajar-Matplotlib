# %% [markdown]
# ## Pertama kita akan memasukan beberapa modules penting yang akan kita gunakan sebelum memulai ketahap selanjutnya
#
# - kita akan memasukan majic komen yaitu %matplotlib inline berfungsi untuk mendirek hasil output nantinya ataub bisa di bilang hasil matplotlib akan di tampilkan di jupyter notebook
#
# - Dan kita juga mengimport 2 modul yaitu matplotlib dan numpy
#
# - %matplotlib notebook

# %%
# %matplotlib notebook

# %%
import matplotlib 
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# - Setelah itu kita akan mengecheck versi dari matplotlib dan numpy yang kita gunakan saat ini

# %%
print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.3.2
# 1.19.2

# %% [markdown]
# ## 3D Axes
#
# - plt.figure = untuk memanggil figure
#
# - plt.axes = untuk memanggil axes
#
# - dan menyertakan nilai 3D

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="431.66664951377516">

# %% [markdown]
# ## 3D Line Plot
#
# - dengan memanfaatkan np.linspace
#
# - dan menggunakan np.cos, np.sin

# %%
z = np.linspace(0, 1, 100)
x = z * np.sin(20 * z)
y = z * np.cos(20 * z)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot(x, y, z, color='red')

ax.set(title='Contoh 3D Line Plot',
      xlabel='Sumbu X',
      ylabel='Sumbu Y',
      zlabel='Sumbu Z')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="431.66664951377516">

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.scatter(x, y, z, color='green')

ax.set(title='Contoh 3D Scatter Plot',
      xlabel='Sumbu X',
      ylabel='Sumbu Y',
      zlabel='Sumbu Z')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="431.66664951377516">
